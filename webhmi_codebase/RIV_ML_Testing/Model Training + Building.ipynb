# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pathlib

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

data_dir = 'ImageData'
data_dir = pathlib.Path(data_dir).with_suffix('')

image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)

## Creating A Data Set


batch_size = 32
img_height = 224
img_width = 224

#Images for Training

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

#Images For Validation

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)

## Visuializing the Data (Not Required)

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break

## Configuring The Data Set For Performace

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
normalization_layer = layers.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))

## Creating The Model

num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

#Compliling The Model

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Showing A Summary Of The Model (Not Required)

model.summary()

## Training A Model Based On The Data Set

epochs=35
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

## Visualizing The Training Results (Not Required)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

## Data Augmentation (For Data Sets like ours without a lot of photos)

data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

## Compiling And Training The Model After Augmenation

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs = 40
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

## Visualizing Training Results Again (Not Required)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

## Save The Model

model.save('Build_Plate_Detection.keras')

# ## Predicitions Based Of the Model using New images

# new_model = tf.keras.models.load_model('Build_Plate_Detection.keras')

# # Show the model architecture
# new_model.summary()

# image_url = "https://tmpfiles.org/dl/5041579/image_20240417_173108.jpg"
# image_path = tf.keras.utils.get_file('Image', origin=image_url)

# img = tf.keras.utils.load_img(
#     image_path, target_size=(img_height, img_width)
# )
# img_array = tf.keras.utils.img_to_array(img)
# img_array = tf.expand_dims(img_array, 0) # Create a batch

# predictions = model.predict(img_array)
# score = tf.nn.softmax(predictions[0])

# print(
#     "This image most likely belongs to {} with a {:.2f} percent confidence."
#     .format(class_names[np.argmax(score)], 100 * np.max(score))
# )
# Out:
# 2741
# Found 2743 files belonging to 2 classes.
# Using 2195 files for training.
# Found 2743 files belonging to 2 classes.
# Using 548 files for validation.
# ['ItemOff', 'ItemOn']
# (32, 224, 224, 3)
# (32,)
# 0.0 0.9607844
# C:\Users\yekut\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       6,422,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,446,498 (24.59 MB)
#  Trainable params: 6,446,498 (24.59 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 15s 194ms/step - accuracy: 0.8810 - loss: 0.5215 - val_accuracy: 0.9471 - val_loss: 0.0604
# Epoch 2/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.9945 - loss: 0.0104 - val_accuracy: 0.9927 - val_loss: 0.0129
# Epoch 3/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9927 - val_loss: 0.0237
# Epoch 4/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9980 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 1.6010e-04
# Epoch 5/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 1.0000 - loss: 5.4528e-05 - val_accuracy: 1.0000 - val_loss: 1.6130e-04
# Epoch 6/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 2.9769e-05 - val_accuracy: 1.0000 - val_loss: 1.5884e-04
# Epoch 7/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 1.0000 - loss: 1.7769e-05 - val_accuracy: 1.0000 - val_loss: 1.2306e-04
# Epoch 8/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 1.0000 - loss: 1.4475e-05 - val_accuracy: 1.0000 - val_loss: 1.1495e-04
# Epoch 9/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 1.0000 - loss: 1.5109e-05 - val_accuracy: 1.0000 - val_loss: 1.0926e-04
# Epoch 10/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 8.5929e-06 - val_accuracy: 1.0000 - val_loss: 8.3268e-05
# Epoch 11/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 6.7811e-06 - val_accuracy: 1.0000 - val_loss: 6.8692e-05
# Epoch 12/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 5.6235e-06 - val_accuracy: 1.0000 - val_loss: 5.8376e-05
# Epoch 13/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 4.8771e-06 - val_accuracy: 1.0000 - val_loss: 5.1548e-05
# Epoch 14/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 4.7257e-06 - val_accuracy: 1.0000 - val_loss: 4.7845e-05
# Epoch 15/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 1.0000 - loss: 3.7478e-06 - val_accuracy: 1.0000 - val_loss: 4.3160e-05
# Epoch 16/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 1.0000 - loss: 4.2540e-06 - val_accuracy: 1.0000 - val_loss: 3.9357e-05
# Epoch 17/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 2.4576e-06 - val_accuracy: 1.0000 - val_loss: 4.4371e-05
# Epoch 18/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 205ms/step - accuracy: 1.0000 - loss: 5.0809e-06 - val_accuracy: 1.0000 - val_loss: 3.0773e-05
# Epoch 19/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 1.0000 - loss: 3.7455e-06 - val_accuracy: 1.0000 - val_loss: 3.1694e-05
# Epoch 20/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - accuracy: 1.0000 - loss: 2.6539e-06 - val_accuracy: 1.0000 - val_loss: 2.9539e-05
# Epoch 21/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 1.0000 - loss: 1.7674e-06 - val_accuracy: 1.0000 - val_loss: 2.6963e-05
# Epoch 22/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 1.0000 - loss: 2.9976e-06 - val_accuracy: 1.0000 - val_loss: 2.4622e-05
# Epoch 23/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 1.0000 - loss: 2.6531e-06 - val_accuracy: 1.0000 - val_loss: 2.4614e-05
# Epoch 24/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 1.0000 - loss: 1.7874e-06 - val_accuracy: 1.0000 - val_loss: 2.2165e-05
# Epoch 25/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 1.0000 - loss: 1.1163e-06 - val_accuracy: 1.0000 - val_loss: 2.3217e-05
# Epoch 26/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 1.0000 - loss: 1.7805e-06 - val_accuracy: 1.0000 - val_loss: 1.8324e-05
# Epoch 27/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 1.0000 - loss: 1.9478e-06 - val_accuracy: 1.0000 - val_loss: 1.8825e-05
# Epoch 28/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 1.0000 - loss: 1.2825e-06 - val_accuracy: 1.0000 - val_loss: 1.7437e-05
# Epoch 29/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - accuracy: 1.0000 - loss: 1.1298e-06 - val_accuracy: 1.0000 - val_loss: 1.5600e-05
# Epoch 30/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 197ms/step - accuracy: 1.0000 - loss: 1.0167e-06 - val_accuracy: 1.0000 - val_loss: 1.4418e-05
# Epoch 31/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 205ms/step - accuracy: 1.0000 - loss: 8.6907e-07 - val_accuracy: 1.0000 - val_loss: 1.4248e-05
# Epoch 32/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 197ms/step - accuracy: 1.0000 - loss: 1.7856e-06 - val_accuracy: 1.0000 - val_loss: 1.2472e-05
# Epoch 33/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 15s 211ms/step - accuracy: 1.0000 - loss: 8.5693e-07 - val_accuracy: 1.0000 - val_loss: 1.2003e-05
# Epoch 34/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 1.0000 - loss: 8.6240e-07 - val_accuracy: 1.0000 - val_loss: 1.1438e-05
# Epoch 35/35
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 1.0000 - loss: 6.3085e-07 - val_accuracy: 1.0000 - val_loss: 1.0350e-05
# Epoch 1/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 0.8622 - loss: 0.3762 - val_accuracy: 0.9836 - val_loss: 0.0477
# Epoch 2/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 273ms/step - accuracy: 0.9929 - loss: 0.0225 - val_accuracy: 0.9927 - val_loss: 0.0307
# Epoch 3/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.9965 - loss: 0.0134 - val_accuracy: 0.9909 - val_loss: 0.0457
# Epoch 4/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.9916 - loss: 0.0223 - val_accuracy: 0.9945 - val_loss: 0.0347
# Epoch 5/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 269ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9945 - val_loss: 0.0146
# Epoch 6/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 267ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9945 - val_loss: 0.0258
# Epoch 7/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 262ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9927 - val_loss: 0.0263
# Epoch 8/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - accuracy: 1.0000 - loss: 3.8147e-04 - val_accuracy: 0.8339 - val_loss: 1.6573
# Epoch 9/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 271ms/step - accuracy: 1.0000 - loss: 1.4683e-04 - val_accuracy: 0.8157 - val_loss: 3.4430
# Epoch 10/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 1.0000 - loss: 5.3365e-04 - val_accuracy: 0.9836 - val_loss: 0.0824
# Epoch 11/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.9956 - loss: 0.0109 - val_accuracy: 0.9745 - val_loss: 0.0882
# Epoch 12/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.9979 - loss: 0.0108 - val_accuracy: 0.9909 - val_loss: 0.0415
# Epoch 13/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.9996 - loss: 0.0037 - val_accuracy: 0.9945 - val_loss: 0.0176
# Epoch 14/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9927 - val_loss: 0.0152
# Epoch 15/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9927 - val_loss: 0.0101
# Epoch 16/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 255ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9982 - val_loss: 0.0038
# Epoch 17/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 18s 265ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 18/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.9999 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 6.4152e-04
# Epoch 19/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.9899 - loss: 0.0455 - val_accuracy: 0.9453 - val_loss: 0.1095
# Epoch 20/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.9974 - loss: 0.0060 - val_accuracy: 0.9945 - val_loss: 0.0381
# Epoch 21/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9891 - val_loss: 0.0795
# Epoch 22/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.9930 - loss: 0.0425 - val_accuracy: 0.9945 - val_loss: 0.0319
# Epoch 23/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 268ms/step - accuracy: 0.9977 - loss: 0.0092 - val_accuracy: 0.9945 - val_loss: 0.0185
# Epoch 24/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 1.0000 - loss: 2.8133e-04 - val_accuracy: 0.9982 - val_loss: 0.0036
# Epoch 25/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.9978 - loss: 0.0072 - val_accuracy: 0.9945 - val_loss: 0.0115
# Epoch 26/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 0.9982 - val_loss: 0.0055
# Epoch 27/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.9996 - loss: 8.3812e-04 - val_accuracy: 1.0000 - val_loss: 8.3669e-04
# Epoch 28/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 235ms/step - accuracy: 0.9912 - loss: 0.0731 - val_accuracy: 0.9927 - val_loss: 0.0339
# Epoch 29/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 235ms/step - accuracy: 0.9943 - loss: 0.0298 - val_accuracy: 0.9945 - val_loss: 0.0331
# Epoch 30/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 234ms/step - accuracy: 0.9990 - loss: 0.0068 - val_accuracy: 0.9945 - val_loss: 0.0366
# Epoch 31/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 233ms/step - accuracy: 0.9981 - loss: 0.0093 - val_accuracy: 0.9945 - val_loss: 0.0361
# Epoch 32/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 234ms/step - accuracy: 0.9987 - loss: 0.0056 - val_accuracy: 0.9945 - val_loss: 0.0253
# Epoch 33/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9945 - val_loss: 0.0128
# Epoch 34/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 241ms/step - accuracy: 0.9981 - loss: 0.0123 - val_accuracy: 0.9945 - val_loss: 0.0264
# Epoch 35/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.9954 - loss: 0.0225 - val_accuracy: 0.9945 - val_loss: 0.0315
# Epoch 36/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.9970 - loss: 0.0131 - val_accuracy: 0.9945 - val_loss: 0.0446
# Epoch 37/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 242ms/step - accuracy: 0.9985 - loss: 0.0074 - val_accuracy: 0.9945 - val_loss: 0.0545
# Epoch 38/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.9975 - loss: 0.0172 - val_accuracy: 0.9945 - val_loss: 0.0244
# Epoch 39/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 242ms/step - accuracy: 0.9976 - loss: 0.0120 - val_accuracy: 0.9945 - val_loss: 0.0296
# Epoch 40/40
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9945 - val_loss: 0.0392
